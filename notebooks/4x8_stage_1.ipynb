# %% [markdown]
# # Model creation stage I (4x8)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Setup

# %% [markdown]
# First we setup the creation by loading in all data

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from tools import common_functions as cf
from tools import regression as reg
from tools import plotting_functions as pf

from tools import sensor_gui as sg

# Folder prefix with all the taxel data
TAXEL_DATA_FOLDER = f"table_calibration/taxel"

# Parameters
SENSOR_LAG = 80 # ms
ARRAY_SIZE = 32

# Automated
data_columns = [f'X{i}' for i in range(ARRAY_SIZE)] + [f'Y{i}' for i in range(ARRAY_SIZE)] + [f'Z{i}' for i in range(ARRAY_SIZE)]

# %% [markdown]
# # STAGE I

# %%
taxels_data = []

for i in range(ARRAY_SIZE):
  
  # ROTATION ANGLES
  # For original calib: 90 + 1.82
  # For new calib: -180 + 1.82 
  taxel_data = cf.prepare_data_for_fitting(f"{TAXEL_DATA_FOLDER}{i}", ARRAY_SIZE, SENSOR_LAG, rotation=90 + 1.82, faulty=False, cut_in_half=True)
  
  # taxel_data = cf.prepare_data_for_fitting(f"{TAXEL_DATA_FOLDER}{i}", ARRAY_SIZE, SENSOR_LAG, rotation=90 - 1.82, faulty=False, cut_in_half=False)
  # taxel_data['F_x'] *= -1
  
  taxels_data.append(taxel_data)
# Out:
# Preparing data for fitting: table_calibration/taxel0
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel1
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel2
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel3
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel4
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel5
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel6
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel7
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel8
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel9
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel10
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel11
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel12
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel13
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel14
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel15
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel16
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel17
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel18
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel19
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel20
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel21
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel22
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel23
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel24
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel25
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel26
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel27
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel28
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel29
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel30
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/taxel31
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])

# %%
cf.prepare_data_for_fitting(f"{TAXEL_DATA_FOLDER}{i}", ARRAY_SIZE, SENSOR_LAG, rotation=90 - 1.82, faulty=False, cut_in_half=False)
# Out:
# Preparing data for fitting: table_calibration/spiral_taxel31
# False True
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:313: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
#        index        t_wall  level_sensor        X0        Y0            Z0  \
# 5          0  1.716388e+09           0.0 -7.062310  2.862564 -1.455600e-07
# 6       1762  1.716388e+09           0.0 -6.588893  2.706825 -1.351204e-07
# 7       1763  1.716388e+09           0.0 -6.115475  2.551086 -1.246784e-07
# 8       1764  1.716388e+09           0.0 -5.642058  2.395347 -1.142339e-07
# 9       1765  1.716388e+09           0.0 -5.168640  2.239608 -1.037870e-07
# ...      ...           ...           ...       ...       ...           ...
# 27779  27779  1.716388e+09           0.0  2.263824 -1.185673  6.662237e-08
# 27780  27780  1.716388e+09           0.0  2.263824 -1.185673  6.662237e-08
# 27781  27781  1.716388e+09           0.0  2.263824 -1.185673  6.662237e-08
# 27782  27782  1.716388e+09           0.0  2.263824 -1.185673  6.662237e-08
# 27783  27783  1.716388e+09           0.0  2.263824 -1.185673  6.662237e-08
#
#              X1        Y1            Z1        X2  ...  level_robot       F_x  \
# 5      4.804230 -4.202142  7.337410e-08  1.173726  ...          0.0 -0.161050
# 6      4.432256 -3.805753  6.324680e-08  1.359941  ...          0.0 -0.166242
# 7      4.060283 -3.409364  5.312126e-08  1.546155  ...          0.0 -0.111034
# 8      3.688309 -3.012976  4.299748e-08  1.732369  ...          0.0 -0.282043
# 9      3.316336 -2.616587  3.287545e-08  1.918584  ...          0.0 -0.225909
# ...         ...       ...           ...       ...  ...          ...       ...
# 27779  1.739328  3.248957 -2.641074e-09 -7.383731  ...          0.0 -0.566621
# 27780  1.739328  3.248957 -2.641074e-09 -7.383731  ...          0.0 -0.393105
# 27781  1.739328  3.248957 -2.641074e-09 -7.383731  ...          0.0 -0.380963
# 27782  1.739328  3.248957 -2.641074e-09 -7.383731  ...          0.0 -0.303049
# 27783  1.739328  3.248957 -2.641074e-09 -7.383731  ...          0.0 -0.550254
#
#             F_y       F_z       T_x       T_y       T_z         X         Y  \
# 5     -0.116265  0.106326 -0.005853 -0.000572 -0.001182  0.317082  0.025401
# 6     -0.064027  0.100085 -0.006978 -0.001812 -0.000550  0.317085  0.025405
# 7     -0.107955  0.125344 -0.003407 -0.001444 -0.002811  0.317099  0.025414
# 8     -0.104028  0.076748 -0.006572 -0.004947 -0.001792  0.317083  0.025425
# 9     -0.071082  0.144576 -0.004608 -0.002584 -0.003208  0.317106  0.025390
# ...         ...       ...       ...       ...       ...       ...       ...
# 27779 -0.108088  0.149080 -0.024819 -0.019959 -0.122063  0.317099  0.025451
# 27780  0.041356  0.051015 -0.020626 -0.018160 -0.121136  0.317115  0.025430
# 27781 -0.177138  0.075989 -0.024758 -0.014507 -0.121781  0.317115  0.025418
# 27782 -0.064889  0.060148 -0.021332 -0.014464 -0.121205  0.317128  0.025403
# 27783 -0.109296  0.033926 -0.023468 -0.019614 -0.122995  0.317115  0.025432
#
#               Z
# 5     -0.146203
# 6     -0.146196
# 7     -0.146189
# 8     -0.146199
# 9     -0.146186
# ...         ...
# 27779 -0.146198
# 27780 -0.146186
# 27781 -0.146183
# 27782 -0.146176
# 27783 -0.146188
#
# [27779 rows x 109 columns]

# %%
plt.plot(taxels_data[0]['F_x'][10000:14000])
plt.plot(taxels_data[0]['F_y'][10000:14000])
# Out:
# /tmp/ipykernel_56303/1992160874.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(taxels_data[0]['F_x'][10000:14000])
# /tmp/ipykernel_56303/1992160874.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(taxels_data[0]['F_y'][10000:14000])

# %%
plt.plot(taxels_data[0]['X0'][10000:14000])
plt.plot(taxels_data[0]['Y0'][10000:14000])
# Out:
# /tmp/ipykernel_56303/1944905297.py:1: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(taxels_data[0]['X0'][10000:14000])
# /tmp/ipykernel_56303/1944905297.py:2: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(taxels_data[0]['Y0'][10000:14000])

# %%
plt.plot(taxels_data[0]['F_y'])

# %%
models = []
MSEs = []
scores = []

for degree in [1,3,5]:
    
    MSEtmp = []
    scoretmp = [] 
     
    for i in range(ARRAY_SIZE):
        
        taxel_data = taxels_data[i]
        
        # Fit the 0.5Hz data to a third order polynomial model
        columns = [f'X{i}', f'Y{i}',f'Z{i}']

        X = taxel_data[columns]
        Y = taxel_data[['F_x', 'F_y', 'F_z']]
        
        # X = taxel_data[columns][taxel_data['F_z'] > -6]
        # Y = taxel_data[['F_x', 'F_y', 'F_z']][taxel_data['F_z'] > -6]
        
        # X = taxel_data[columns][np.abs(taxel_data['F_x']) < 2.5][np.abs(taxel_data['F_y']) < 2.5]
        # Y = taxel_data[['F_x', 'F_y', 'F_z']][np.abs(taxel_data['F_x']) < 2.5][np.abs(taxel_data['F_y']) < 2.5]
        
        print(f"\nFitting taxel {i}:")
        model, _, X_test, _, Y_test = reg.create_regression_pipeline_and_fit(X, Y, False, degree=degree)
        model.taxel_index = i
        
        if degree == 3:
            models.append(model)
        
        # MSE 
        Y_pred = model.predict(X_test)
        N, _ = Y_pred.shape
        
        mse_custom = np.sum((Y_test - Y_pred) ** 2) / N    

        max = np.max(Y_pred, axis=0)
        min = np.min(Y_pred, axis=0)
        
        diff = max - min
        
        print(diff)
        
        for i in range(3):
            mse_custom[i] = mse_custom[i] / diff[i]
            
        mse_custom = np.sum(mse_custom) / 3
        
        MSEtmp.append(mse_custom)
        scoretmp.append(model.score(X_test, Y_test))
        
        print(f"MSE: {mse_custom}")
        print(f"Score: {model.score(X_test, Y_test)}")
        
    MSEs.append(MSEtmp)
    scores.append(scoretmp)
# Out:
# Fitting taxel 0:
# [10.14816089  9.1359217   8.86063837]
# MSE: 0.04792614324182645
# Score: 0.880452631405177
#
# Fitting taxel 1:
# [10.18841076  9.56382556  9.33380223]
# MSE: 0.034087275912780705
# Score: 0.9030446039408527
#
# Fitting taxel 2:
# [ 9.91706079 10.0393961   9.14303089]
# MSE: 0.05697309580568038
# Score: 0.8575397605929949
#
# Fitting taxel 3:
# [10.48870172  8.96155205  8.22439614]
# MSE: 0.04068447776699519
# Score: 0.8983872662877009
#
# Fitting taxel 4:
# [9.86856734 8.90811295 8.03931815]
# MSE: 0.03135850641274771
# Score: 0.921334805850655
#
# Fitting taxel 5:
# [10.21038721  9.28593642  8.54208252]
# MSE: 0.01715007180164887
# Score: 0.9429073186450846
#
# Fitting taxel 6:
# [10.97967052  9.29748901 15.3071575 ]
# MSE: 0.028349101470615923
# Score: 0.8978700068147091
#
# Fitting taxel 7:
# [10.73128585  8.74512061 12.9957341 ]
# MSE: 0.021614601730209657
# Score: 0.9194166110551806
#
# Fitting taxel 8:
# [9.6046127  8.36584092 8.20683849]
# MSE: 0.02709115019286075
# Score: 0.9253117866395829
#
# Fitting taxel 9:
# [10.84503648  8.94612625  7.96117265]
# MSE: 0.03292651824867058
# Score: 0.928884718050721
#
# Fitting taxel 10:
# [11.59127395 17.00718262 14.47127417]
# MSE: 0.014217883208677414
# Score: 0.9423510841177665
#
# Fitting taxel 11:
# [11.32795737  9.20988674  8.60874827]
# MSE: 0.023976608509960695
# Score: 0.9395498237535915
#
# Fitting taxel 12:
# [11.08245762  7.6310256   7.37025995]
# MSE: 0.10234338263753251
# Score: 0.6808283755397198
#
# Fitting taxel 13:
# [10.38125723  9.08228345 11.10198474]
# MSE: 0.028246157723763543
# Score: 0.920398484609362
#
# Fitting taxel 20:
# [ 12.23241427  49.64612202 296.06267346]
# MSE: 0.5428791658698077
# Score: -28.64634964632732
#
# Fitting taxel 21:
# [ 16.28946471  18.60418884 141.36239506]
# MSE: 0.19341196858925716
# Score: -4.379449573260604
#
# Fitting taxel 22:
# [12.04931973 10.16560713  7.8427328 ]
# MSE: 0.15453254249548562
# Score: 0.743351686674134
#
# Fitting taxel 23:
# [12.63831338 11.4067491  11.43838907]
# MSE: 0.039104413381011026
# Score: 0.8454825677029939
#
# Fitting taxel 24:
# [ 12.83185797  25.63511933 110.83231776]
# MSE: 0.25995906392901225
# Score: -4.43840101827831
#
# Fitting taxel 25:
# [  19.66022491    9.6109756  2430.54520883]
# MSE: 1.180850742279936
# Score: -572.7664976639865
#
# Fitting taxel 26:
# [12.17894402 10.22353757  5.26535822]
# MSE: 0.2413778602907887
# Score: 0.7233778655301982
#
# Fitting taxel 27:
# [ 11.87481756  25.94641705 156.29276923]
# MSE: 0.1294280597568322
# Score: -2.663230989465892
#
# Fitting taxel 28:
# [ 40.76648114  64.0933588  368.49001361]
# MSE: 0.5629814199436207
# Score: -37.411992733309106
#
# Fitting taxel 29:
# [11.51144045  9.70026263 14.82315774]
# MSE: 0.1448455474313269
# Score: 0.5419886435545864
#
# Fitting taxel 30:
# [11.95708964  9.55287785  7.24071753]
# MSE: 0.179898532777117
# Score: 0.7122399769983238
#
# Fitting taxel 31:
# [23.5775281  23.9186866  80.52903858]
# MSE: 0.05710677366120246
# Score: 0.18105478959549873

# %%
# Construct the latex table body
table_body = ""

for i in range(ARRAY_SIZE):
    table_body += f"Taxel {i} "
    
    for j in range(3):
        table_body += f"& \multicolumn{{1}}{{l|}}{{{scores[j][i]:.5f}}} & {MSEs[j][i]:.5f} "
    
    table_body += "\\\\ \hline \n"

print(table_body)
# Out:
# Taxel 0 & \multicolumn{1}{l|}{0.88045} & 0.04793 & \multicolumn{1}{l|}{0.95049} & 0.01082 & \multicolumn{1}{l|}{-12.16822} & 0.48072 \\ \hline
# Taxel 1 & \multicolumn{1}{l|}{0.90304} & 0.03409 & \multicolumn{1}{l|}{0.95635} & 0.00931 & \multicolumn{1}{l|}{-0.08954} & 0.11592 \\ \hline
# Taxel 2 & \multicolumn{1}{l|}{0.85754} & 0.05697 & \multicolumn{1}{l|}{0.95157} & 0.01201 & \multicolumn{1}{l|}{0.84358} & 0.04866 \\ \hline
# Taxel 3 & \multicolumn{1}{l|}{0.89839} & 0.04068 & \multicolumn{1}{l|}{0.95066} & 0.01147 & \multicolumn{1}{l|}{0.84584} & 0.05832 \\ \hline
# Taxel 4 & \multicolumn{1}{l|}{0.92133} & 0.03136 & \multicolumn{1}{l|}{0.79877} & 0.07773 & \multicolumn{1}{l|}{0.72221} & 0.06467 \\ \hline
# Taxel 5 & \multicolumn{1}{l|}{0.94291} & 0.01715 & \multicolumn{1}{l|}{0.95405} & 0.01331 & \multicolumn{1}{l|}{0.76954} & 0.13205 \\ \hline
# Taxel 22 & \multicolumn{1}{l|}{0.95097} & 0.01736 & \multicolumn{1}{l|}{0.98118} & 0.00440 & \multicolumn{1}{l|}{0.74335} & 0.15453 \\ \hline
# Taxel 23 & \multicolumn{1}{l|}{0.86518} & 0.03004 & \multicolumn{1}{l|}{0.89836} & 0.02698 & \multicolumn{1}{l|}{0.84548} & 0.03910 \\ \hline
# Taxel 24 & \multicolumn{1}{l|}{0.91125} & 0.02712 & \multicolumn{1}{l|}{0.83146} & 0.03592 & \multicolumn{1}{l|}{-4.43840} & 0.25996 \\ \hline
# Taxel 25 & \multicolumn{1}{l|}{0.92390} & 0.01188 & \multicolumn{1}{l|}{0.97430} & 0.00730 & \multicolumn{1}{l|}{-572.76650} & 1.18085 \\ \hline
# Taxel 26 & \multicolumn{1}{l|}{0.94919} & 0.01580 & \multicolumn{1}{l|}{0.97881} & 0.00513 & \multicolumn{1}{l|}{0.72338} & 0.24138 \\ \hline
# Taxel 27 & \multicolumn{1}{l|}{0.90533} & 0.02977 & \multicolumn{1}{l|}{0.97077} & 0.00722 & \multicolumn{1}{l|}{-2.66323} & 0.12943 \\ \hline
# Taxel 28 & \multicolumn{1}{l|}{0.89574} & 0.03637 & \multicolumn{1}{l|}{0.83031} & 0.05560 & \multicolumn{1}{l|}{-37.41199} & 0.56298 \\ \hline
# Taxel 29 & \multicolumn{1}{l|}{0.87739} & 0.04410 & \multicolumn{1}{l|}{0.94120} & 0.01504 & \multicolumn{1}{l|}{0.54199} & 0.14485 \\ \hline
# Taxel 30 & \multicolumn{1}{l|}{0.87178} & 0.04430 & \multicolumn{1}{l|}{0.93898} & 0.01804 & \multicolumn{1}{l|}{0.71224} & 0.17990 \\ \hline
# Taxel 31 & \multicolumn{1}{l|}{0.91990} & 0.02715 & \multicolumn{1}{l|}{0.95686} & 0.01142 & \multicolumn{1}{l|}{0.18105} & 0.05711 \\ \hline

# %%
for j in range(3):
  
  # Calc mean score and mse
  mean_score = np.mean(scores[j])
  mean_mse = np.mean(MSEs[j])
  
  # Calc std score and mse
  std_score = np.std(scores[j])
  std_mse = np.std(MSEs[j])    
  
  print(f"Degree {2*j + 1}: Mean score: {mean_score:.5f} +- {std_score:.5f}, Mean MSE: {mean_mse:.5f} +- {std_mse:.5f}")
# Out:
# Degree 1: Mean score: 0.90495 +- 0.04907, Mean MSE: 0.03263 +- 0.01784
# Degree 3: Mean score: 0.93886 +- 0.05974, Mean MSE: 0.01693 +- 0.01809
# Degree 5: Mean score: -24.01625 +- 99.81791, Mean MSE: 0.23346 +- 0.24232

# %%
import matplotlib.pyplot as plt

# Set font properties for the plot
plt.rcParams["font.family"] = "UGent Panno Text"
plt.rcParams["font.size"] = 28

TAXEL_ID = 0

# Ensure that there are models loaded
if len(models) > 0:
    model = models[TAXEL_ID]
else:
    raise ValueError("No models found.")

# Extract prediction data
columns = [f'X{TAXEL_ID}', f'Y{TAXEL_ID}', f'Z{TAXEL_ID}']
Y_pred = model.predict(taxels_data[TAXEL_ID][columns])

# Split predicted data into components
pred_X = Y_pred[:, 0]
pred_Y = Y_pred[:, 1]
pred_Z = Y_pred[:, 2]

# Create subplots
fig, ax = plt.subplots(3, 1, figsize=(20, 15), sharex=True, sharey=False)

# Define common labels and titles
axes_labels = ['$F_x$', '$F_y$', '$F_z$']
axes_vals = ['F_x', 'F_y', 'F_z']
pred_labels = ['$\hat{F_x}$', '$\hat{F_y}$', '$\hat{F_z}$']
titles = ['X-axis Force Prediction', 'Y-axis Force Prediction', 'Z-axis Force Prediction']
colors = ['r', 'g', 'b']

t = np.linspace(0, int(50), pred_X.shape[0])

for i, axi in enumerate(ax):
    axi.plot(t, taxels_data[TAXEL_ID][axes_vals[i]], label=f'{axes_labels[i]}')
    axi.plot(t, Y_pred[:, i], label=pred_labels[i])
    axi.set_ylabel('Force [N]')
    # axi.set_title(titles[i])
    axi.legend()
    axi.grid(True)

# Set common x-label for the entire figure
ax[-1].set_xlabel('Time [s]')
# ax[-1].set_xlim([0, 50])
# Add a main title for the figure
# fig.suptitle('Model Predictions vs. Actual F/T Readings', fontsize=22)

# Adjust layout for better spacing
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# Save the figure if needed
# plt.savefig('model_predictions.png', dpi=300)

# Show the plot
plt.savefig("plots/c4_stageI_fit_alt.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, axs = plt.subplots(3, 1, figsize=(25, 15), sharex=True)

axs[0].plot(t[:70000], taxels_data[0]['Z0'][:70000])
axs[0].set_ylabel(f'$1/z_0$ [$1/\mu T$]')
axs[0].grid(True)

axs[1].plot(t[:70000], taxels_data[15]['Z15'][:70000])
axs[1].set_ylabel(f'$1/z_{{15}}$ [$1/\mu T$]')
axs[1].grid(True)

axs[2].plot(t[:70000], taxels_data[28]['Z28'][:70000])
axs[2].set_ylabel(f'$1/z_{{28}}$ [$1/\mu T$]')
axs[2].grid(True)
axs[2].set_xlabel('Time [s]')

plt.xlim([t[0], 47])

plt.savefig("plots/c3_differences.pdf", format="pdf", bbox_inches="tight")
# Out:
# /tmp/ipykernel_139090/1581564216.py:3: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   axs[0].plot(t[:70000], taxels_data[0]['Z0'][:70000])
# /tmp/ipykernel_139090/1581564216.py:7: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   axs[1].plot(t[:70000], taxels_data[15]['Z15'][:70000])
# /tmp/ipykernel_139090/1581564216.py:11: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   axs[2].plot(t[:70000], taxels_data[28]['Z28'][:70000])

# %%
# Now we save all models
for model in models:
  reg.save_taxel_models(model, f"4x8", f"taxel{model.taxel_index}_alt")

# %%
# Also make one big giant model --> phase I
class StageIModel:
  def __init__(self, component_models) -> None:
    
    self.component_models = component_models
  
  def predict(self, df):
    
    Ys = []
    for i in range(len(self.component_models)):
      model = self.component_models[i]
      X = df[[f'X{i}', f'Y{i}',f'Z{i}']]
      Y = model.predict(X)
      Ys.append(Y)
    
    return np.array(Ys)
  
stage_I_model = StageIModel(models)
reg.save_taxel_models(stage_I_model, f"4x8", f"stageI_alt")

# %%
plt.plot(taxels_data[0]['F_x'], Y_pred[:, 0])
