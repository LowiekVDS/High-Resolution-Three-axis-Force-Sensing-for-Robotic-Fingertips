# %% [markdown]
# # Single taxil calibration
# This notebook implements a model to calibrate a single taxel

# %%
# Imports
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import os
import numpy as np

# Parameters
SENSOR_LAG = 25 # ms
TAXEL_INDEX = 3
ARRAY_SIZE = 2*2
NAME = "H1_5_s" + str(TAXEL_INDEX)
ANGLE_CLIP_THRESHOLD = 0.1

# %%
TF_file = f'../scripts/FT300-S_force_torque/data/{NAME}.csv'
sensor_file = f'../scripts/2x2_sensor/data/{NAME}.csv'

# Load the data from the CSV file into a pandas DataFrame
TFdata = pd.read_csv(os.path.join(os.getcwd(), TF_file))
sensordata = pd.read_csv(os.path.join(os.getcwd(), sensor_file))

# Remove units
for col in TFdata.columns:
  TFdata[col .split(' ')[0]] = TFdata[col]
  
for col in sensordata.columns:
  sensordata[col .split(' ')[0]] = sensordata[col]
  
# Add column for chosen taxel. Improves readability in code
sensordata['X'] = sensordata[f'X{TAXEL_INDEX}']
sensordata['Y'] = sensordata[f'Y{TAXEL_INDEX}']
sensordata['Z'] = sensordata[f'Z{TAXEL_INDEX}']
  
TFdata.drop(TFdata.columns[0:8], axis=1, inplace=True)
sensordata.drop(sensordata.columns[0:13], axis=1, inplace=True)

TFdata.info()
sensordata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12870 entries, 0 to 12869
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   t_wall   12870 non-null  float64
#  1   t_robot  12870 non-null  float64
#  2   F_x      12870 non-null  float64
#  3   F_y      12870 non-null  float64
#  4   F_z      12870 non-null  float64
#  5   T_x      12870 non-null  float64
#  6   T_y      12870 non-null  float64
#  7   T_z      12870 non-null  float64
# dtypes: float64(8)
# memory usage: 804.5 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5673 entries, 0 to 5672
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   t_wall  5673 non-null   float64
#  1   X0      5673 non-null   float64
#  2   Y0      5673 non-null   float64
#  3   Z0      5673 non-null   float64
#  4   X1      5673 non-null   float64
#  5   Y1      5673 non-null   float64
#  6   Z1      5673 non-null   float64
#  7   X2      5673 non-null   float64
#  8   Y2      5673 non-null   float64
#  9   Z2      5673 non-null   float64
#  10  X3      5673 non-null   float64
#  11  Y3      5673 non-null   float64
#  12  Z3      5673 non-null   float64
#  13  X       5673 non-null   float64
#  14  Y       5673 non-null   float64
#  15  Z       5673 non-null   float64
# dtypes: float64(16)
# memory usage: 709.2 KB

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Time synchronization
# From analysis, the sensor lags behind. So do the wall time (the one used to sync) of sensor

# %%
sensordata['t_wall'] -= SENSOR_LAG/1000

# %% [markdown]
# ### Interpolation
# We need to cutoff the rows so they start at the same time, then interpolate

# %%
sensor_is_first = sensordata['t_wall'][0] < TFdata['t_wall'][0]
sensor_is_last = sensordata['t_wall'][len(sensordata)-1] > TFdata['t_wall'][len(TFdata)-1]

if sensor_is_first:
  start = TFdata['t_wall'][0]
else:
  start = sensordata['t_wall'][0]
  
if sensor_is_last:
  end = sensordata['t_wall'][len(sensordata)-1]
else:
  end = TFdata['t_wall'][len(TFdata)-1]
  
# Clip data to start at the same time and also to end at the same time
TFdata = TFdata[TFdata['t_wall'] >= start]
sensordata = sensordata[sensordata['t_wall'] >= start]
TFdata = TFdata[TFdata['t_wall'] <= end]
sensordata = sensordata[sensordata['t_wall'] <= end]

# %%
is_sensor_faster = len(sensordata) > len(TFdata)

combined = pd.concat([sensordata, TFdata], ignore_index=True, sort=False).sort_values(by=['t_wall'])

combined.set_index('t_wall')
combined = combined.apply(lambda x: x.interpolate(method='linear')).reset_index()

# Filter out only the ones I need
combined = combined[['X', 'Y', 'Z', 'F_x', 'F_y', 'F_z', 't_wall']]

# %% [markdown]
# ### Normalization
# First we normalize our sensor data (beforehand instead of in the pipeline) so that it is easier to visualize and inspect. Normalization pipeline:
# - Remove average of first 100 samples
# - Convert to mT instead of uT

# %%
for letter in ['X', 'Y', 'Z']:
  combined[letter] -= np.mean(combined[letter][:100])
  combined[letter] /= 1000

# %% [markdown]
# ### Analysis
# Some visualisations of the data

# %%
plt.plot(combined['t_wall'], combined['F_x'], label='Fx')
plt.plot(combined['t_wall'], combined['F_y'], label='Fy')
plt.plot(combined['t_wall'], combined['F_z'], label='Fz')
plt.legend()

# %%
plt.plot(combined['t_wall'], combined['X'], label='X')
plt.plot(combined['t_wall'], combined['Y'], label='Y')
plt.plot(combined['t_wall'], combined['Z'], label='Z')
plt.legend()

# %%
plt.plot(combined['t_wall'], combined['X'])
plt.plot(combined['t_wall'], combined['F_x'], label='Fz')

# %%
plt.scatter(combined['Z'], combined['F_z'], s=0.1)
Bz = lambda z: 1/(-5.5-z)**3 * 5

zs = np.linspace(-4.5, 0, 100)

# plt.plot(zs, [Bz(z) for z in zs], color='red')

# %%
plt.scatter(combined['X'], combined['F_x'], s=0.1)
plt.scatter(combined['Y'], combined['F_y'], s=0.1)

# %% [markdown]
# ### Add features

# %% [markdown]
# Only the magnitude (in XY plane and overall) seem to be useful

# %%
combined['TF_magnitude'] = np.sqrt(combined['F_x']**2 + combined['F_y']**2 + combined['F_z']**2)
combined['TF_magnitude_XY'] = np.sqrt(combined['F_x']**2 + combined['F_y']**2)

combined['sens_magnitude'] = np.sqrt(combined['X']**2 + combined['Y']**2 + combined['Z']**2)
combined['sens_magnitude_XY'] = np.sqrt(combined['X']**2 + combined['Y']**2)

# %%
plt.plot(combined['t_wall'], combined['TF_magnitude'], label='magnitude')
plt.plot(combined['t_wall'], combined['TF_magnitude_XY'], label='magnitude_XY')
plt.legend()

# %%
plt.plot(combined['t_wall'], combined['sens_magnitude'], label='magnitude')
plt.plot(combined['t_wall'], combined['sens_magnitude_XY'], label='magnitude_XY')
plt.legend()

# %%
plt.scatter(combined['sens_magnitude'], combined['TF_magnitude'], s=0.1)

# %%
plt.scatter(combined['sens_magnitude_XY'], combined['TF_magnitude_XY'], s=0.1)

# %% [markdown]
# # Linear regression
# First we try basic linear regression.

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

# %%
X = combined[['X', 'Y', 'Z', 'sens_magnitude', 'sens_magnitude_XY']][1:]
Y = combined[['F_x', 'F_y', 'F_z', 'TF_magnitude', 'TF_magnitude_XY']][1:]

print(X.shape, Y.shape)

# Different model per thing
model = LinearRegression()

model.fit(X, Y)
print("Score: ", model.score(X, Y))
print("MSE: ", mean_squared_error(Y, model.predict(X)))
# Out:
# (18528, 5) (18528, 5)
# Score:  0.8469560815115964
# MSE:  0.05641768770424318

# %%
Y_pred = model.predict(X)

# %%
# Some functions
def plot_predictions(Y, Y_pred):
  
  subplot_index = Y.shape[1] * 100 + 11
  
  for i in range(Y.shape[1]):
    
    plt.subplot(subplot_index + i)
    plt.plot(Y[:,i], label='true')
    plt.plot(Y_pred[:,i], label='pred')

  plt.show()
  
def calculate_RMSE(Y, Y_pred):
  
  RMSE = np.zeros(Y.shape[1])
  
  for i in range(Y.shape[1]):
    RMSE[i] = np.sqrt(np.mean((Y[:,i] - Y_pred[:,i])**2))
    
  return RMSE

def calculate_error(Y, Y_pred):
    
    error = np.zeros(Y.shape)
    
    for i in range(Y.shape[1]):
      error[:, i] = np.abs(Y[:,i] - Y_pred[:,i])
      
    return error

def plot_curves(x):
  index = 1
  subplot_index = x.shape[1] * 100 + 11
  
  for i in range(x.shape[1]):
    plt.subplot(subplot_index + i)
    plt.plot(x[:, i], label='RMSE')
    
    index += 1

  plt.show()

# %%
plot_predictions(Y.to_numpy(), Y_pred)
plot_curves(calculate_error(Y.to_numpy(), Y_pred))

# %%
index = 2

plt.plot(Y.to_numpy()[:, index], label='true')
plt.plot(Y_pred[:, index], label='pred')
plt.legend()
# plt.xlim((6000,9000))

# %% [markdown]
# # HistBoostingRegression

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
# Make a custom (train, val) / test split
X = combined[['X', 'Y', 'Z', 'sens_magnitude', 'sens_magnitude_XY']][1:]
y = combined[['F_x']][1:]

X_train, X_test, y_train, y_test = train_test_split(X.to_numpy(), y.to_numpy(), test_size=0.2, shuffle=True)

# # First we take out all the parts that interest us
# ranges = [(2000, 2600), (3400, 4100), (4800, 5900), (6850, 7800), (8700, 9700)]
# indices = []

# for j in range(len(ranges)):

#   indices += [i for i in range(ranges[j][0], ranges[j][1])]
  
#   plt.plot(combined['t_wall'][ranges[j][0]:ranges[j][1]], combined['TF_magnitude'][ranges[j][0]:ranges[j][1]], label=f'{j}', color='green')
  
#   if j < len(ranges) - 1:
#     plt.plot(combined['t_wall'][ranges[j][1]:ranges[j+1][0]], combined['TF_magnitude'][ranges[j][1]:ranges[j+1][0]], label=f'{j}', color='red')
#   else:
#     plt.plot(combined['t_wall'][ranges[j][1]:], combined['TF_magnitude'][ranges[j][1]:], label=f'{j}', color='red')

# %%
param_grid = {
    "max_depth": [1, 2, 4, 6, 8, 10],
    "learning_rate": np.linspace(0.01, 0.2, 5),
}

reg = HistGradientBoostingRegressor()

gridsearch = GridSearchCV(reg, param_grid=param_grid, verbose=10, return_train_score=True, n_jobs=8)

# %%
gridsearch.fit(X_train, y_train[:, 0])
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5; 1/30] START learning_rate=0.01, max_depth=1............................
# [CV 2/5; 1/30] START learning_rate=0.01, max_depth=1............................
# [CV 3/5; 1/30] START learning_rate=0.01, max_depth=1............................
# [CV 4/5; 1/30] START learning_rate=0.01, max_depth=1............................
# [CV 5/5; 1/30] START learning_rate=0.01, max_depth=1............................
# [CV 1/5; 2/30] START learning_rate=0.01, max_depth=2............................
# [CV 2/5; 2/30] START learning_rate=0.01, max_depth=2............................
# [CV 3/5; 2/30] START learning_rate=0.01, max_depth=2............................
# [CV 2/5; 1/30] END learning_rate=0.01, max_depth=1;, score=(train=0.540, test=0.528) total time=   0.1s
# [CV 4/5; 2/30] START learning_rate=0.01, max_depth=2............................
# [CV 5/5; 1/30] END learning_rate=0.01, max_depth=1;, score=(train=0.534, test=0.550) total time=   0.1s
# [CV 5/5; 2/30] START learning_rate=0.01, max_depth=2............................
# [CV 4/5; 1/30] END learning_rate=0.01, max_depth=1;, score=(train=0.539, test=0.527) total time=   0.1s
# [CV 1/5; 3/30] START learning_rate=0.01, max_depth=4............................
# [CV 1/5; 1/30] END learning_rate=0.01, max_depth=1;, score=(train=0.535, test=0.531) total time=   0.1s
# [CV 2/5; 3/30] START learning_rate=0.01, max_depth=4............................
# [CV 3/5; 1/30] END learning_rate=0.01, max_depth=1;, score=(train=0.533, test=0.541) total time=   0.1s
# [CV 3/5; 3/30] START learning_rate=0.01, max_depth=4............................
# [CV 2/5; 2/30] END learning_rate=0.01, max_depth=2;, score=(train=0.653, test=0.637) total time=   0.1s
# [CV 4/5; 3/30] START learning_rate=0.01, max_depth=4............................
# [CV 1/5; 2/30] END learning_rate=0.01, max_depth=2;, score=(train=0.649, test=0.641) total time=   0.1s
# [CV 5/5; 3/30] START learning_rate=0.01, max_depth=4............................
# [CV 3/5; 2/30] END learning_rate=0.01, max_depth=2;, score=(train=0.648, test=0.655) total time=   0.1s
# [CV 1/5; 4/30] START learning_rate=0.01, max_depth=6............................
# [CV 4/5; 2/30] END learning_rate=0.01, max_depth=2;, score=(train=0.653, test=0.644) total time=   0.1s
# [CV 2/5; 4/30] START learning_rate=0.01, max_depth=6............................
# [CV 5/5; 2/30] END learning_rate=0.01, max_depth=2;, score=(train=0.649, test=0.660) total time=   0.1s
# [CV 4/5; 4/30] START learning_rate=0.01, max_depth=6............................
# [CV 4/5; 3/30] END learning_rate=0.01, max_depth=4;, score=(train=0.723, test=0.711) total time=   0.2s
# [CV 1/5; 5/30] START learning_rate=0.01, max_depth=8............................
# [CV 5/5; 3/30] END learning_rate=0.01, max_depth=4;, score=(train=0.719, test=0.722) total time=   0.3s
# [CV 3/5; 5/30] START learning_rate=0.01, max_depth=8............................
# [CV 1/5; 3/30] END learning_rate=0.01, max_depth=4;, score=(train=0.720, test=0.710) total time=   0.3s
# [CV 5/5; 5/30] START learning_rate=0.01, max_depth=8............................
# [CV 2/5; 3/30] END learning_rate=0.01, max_depth=4;, score=(train=0.722, test=0.709) total time=   0.3s
# [CV 3/5; 3/30] END learning_rate=0.01, max_depth=4;, score=(train=0.717, test=0.725) total time=   0.3s
# [CV 2/5; 6/30] START learning_rate=0.01, max_depth=10...........................
# [CV 4/5; 6/30] START learning_rate=0.01, max_depth=10...........................
# [CV 2/5; 4/30] END learning_rate=0.01, max_depth=6;, score=(train=0.745, test=0.735) total time=   0.4s
# [CV 3/5; 4/30] START learning_rate=0.01, max_depth=6............................
# [CV 1/5; 4/30] END learning_rate=0.01, max_depth=6;, score=(train=0.743, test=0.728) total time=   0.5s
# [CV 1/5; 7/30] START learning_rate=0.0575, max_depth=1..........................
# [CV 4/5; 4/30] END learning_rate=0.01, max_depth=6;, score=(train=0.746, test=0.736) total time=   0.4s
# [CV 5/5; 4/30] START learning_rate=0.01, max_depth=6............................
# [CV 1/5; 7/30] END learning_rate=0.0575, max_depth=1;, score=(train=0.792, test=0.788) total time=   0.1s
# [CV 2/5; 7/30] START learning_rate=0.0575, max_depth=1..........................
# [CV 1/5; 5/30] END learning_rate=0.01, max_depth=8;, score=(train=0.746, test=0.731) total time=   0.4s
# [CV 2/5; 5/30] START learning_rate=0.01, max_depth=8............................
# [CV 2/5; 7/30] END learning_rate=0.0575, max_depth=1;, score=(train=0.793, test=0.776) total time=   0.1s
# [CV 3/5; 7/30] START learning_rate=0.0575, max_depth=1..........................
# [CV 3/5; 5/30] END learning_rate=0.01, max_depth=8;, score=(train=0.744, test=0.745) total time=   0.4s
# [CV 4/5; 5/30] START learning_rate=0.01, max_depth=8............................
# [CV 3/5; 7/30] END learning_rate=0.0575, max_depth=1;, score=(train=0.789, test=0.799) total time=   0.1s
# [CV 4/5; 7/30] START learning_rate=0.0575, max_depth=1..........................
# [CV 3/5; 4/30] END learning_rate=0.01, max_depth=6;, score=(train=0.743, test=0.743) total time=   0.4s
# [CV 5/5; 7/30] START learning_rate=0.0575, max_depth=1..........................
# [CV 5/5; 5/30] END learning_rate=0.01, max_depth=8;, score=(train=0.745, test=0.745) total time=   0.6s
# [CV 1/5; 6/30] START learning_rate=0.01, max_depth=10...........................
# [CV 2/5; 6/30] END learning_rate=0.01, max_depth=10;, score=(train=0.745, test=0.734) total time=   0.6s
# [CV 3/5; 6/30] START learning_rate=0.01, max_depth=10...........................
# [CV 4/5; 7/30] END learning_rate=0.0575, max_depth=1;, score=(train=0.795, test=0.782) total time=   0.1s
# [CV 2/5; 8/30] START learning_rate=0.0575, max_depth=2..........................
# [CV 4/5; 6/30] END learning_rate=0.01, max_depth=10;, score=(train=0.748, test=0.737) total time=   0.6s
# [CV 5/5; 6/30] START learning_rate=0.01, max_depth=10...........................
# [CV 5/5; 4/30] END learning_rate=0.01, max_depth=6;, score=(train=0.744, test=0.744) total time=   0.4s
# [CV 4/5; 8/30] START learning_rate=0.0575, max_depth=2..........................
# [CV 5/5; 7/30] END learning_rate=0.0575, max_depth=1;, score=(train=0.792, test=0.800) total time=   0.1s
# [CV 1/5; 8/30] START learning_rate=0.0575, max_depth=2..........................
# [CV 2/5; 8/30] END learning_rate=0.0575, max_depth=2;, score=(train=0.844, test=0.833) total time=   0.1s
# [CV 3/5; 8/30] START learning_rate=0.0575, max_depth=2..........................
# [CV 4/5; 8/30] END learning_rate=0.0575, max_depth=2;, score=(train=0.846, test=0.828) total time=   0.1s
# [CV 5/5; 8/30] START learning_rate=0.0575, max_depth=2..........................
# [CV 2/5; 5/30] END learning_rate=0.01, max_depth=8;, score=(train=0.747, test=0.735) total time=   0.4s
# [CV 1/5; 8/30] END learning_rate=0.0575, max_depth=2;, score=(train=0.843, test=0.837) total time=   0.1s
# [CV 1/5; 9/30] START learning_rate=0.0575, max_depth=4..........................
# [CV 3/5; 9/30] START learning_rate=0.0575, max_depth=4..........................
# [CV 3/5; 8/30] END learning_rate=0.0575, max_depth=2;, score=(train=0.839, test=0.846) total time=   0.1s
# [CV 5/5; 9/30] START learning_rate=0.0575, max_depth=4..........................
# [CV 5/5; 8/30] END learning_rate=0.0575, max_depth=2;, score=(train=0.842, test=0.844) total time=   0.1s
# [CV 2/5; 10/30] START learning_rate=0.0575, max_depth=6.........................
# [CV 4/5; 5/30] END learning_rate=0.01, max_depth=8;, score=(train=0.748, test=0.738) total time=   0.6s
# [CV 4/5; 10/30] START learning_rate=0.0575, max_depth=6.........................
# [CV 3/5; 9/30] END learning_rate=0.0575, max_depth=4;, score=(train=0.870, test=0.872) total time=   0.2s
# [CV 4/5; 9/30] START learning_rate=0.0575, max_depth=4..........................
# [CV 1/5; 9/30] END learning_rate=0.0575, max_depth=4;, score=(train=0.872, test=0.863) total time=   0.2s
# [CV 2/5; 9/30] START learning_rate=0.0575, max_depth=4..........................
# [CV 5/5; 9/30] END learning_rate=0.0575, max_depth=4;, score=(train=0.873, test=0.866) total time=   0.2s
# [CV 1/5; 10/30] START learning_rate=0.0575, max_depth=6.........................
# [CV 1/5; 6/30] END learning_rate=0.01, max_depth=10;, score=(train=0.744, test=0.730) total time=   0.6s
# [CV 1/5; 11/30] START learning_rate=0.0575, max_depth=8.........................
# [CV 5/5; 6/30] END learning_rate=0.01, max_depth=10;, score=(train=0.746, test=0.744) total time=   0.6s
# [CV 3/5; 6/30] END learning_rate=0.01, max_depth=10;, score=(train=0.743, test=0.746) total time=   0.6s
# [CV 3/5; 11/30] START learning_rate=0.0575, max_depth=8.........................
# [CV 5/5; 11/30] START learning_rate=0.0575, max_depth=8.........................
# [CV 4/5; 9/30] END learning_rate=0.0575, max_depth=4;, score=(train=0.876, test=0.850) total time=   0.2s
# [CV 2/5; 12/30] START learning_rate=0.0575, max_depth=10........................
# [CV 2/5; 9/30] END learning_rate=0.0575, max_depth=4;, score=(train=0.874, test=0.863) total time=   0.2s
# [CV 4/5; 12/30] START learning_rate=0.0575, max_depth=10........................
# [CV 2/5; 10/30] END learning_rate=0.0575, max_depth=6;, score=(train=0.888, test=0.871) total time=   0.3s
# [CV 3/5; 10/30] START learning_rate=0.0575, max_depth=6.........................
# [CV 4/5; 10/30] END learning_rate=0.0575, max_depth=6;, score=(train=0.890, test=0.859) total time=   0.4s
# [CV 5/5; 10/30] START learning_rate=0.0575, max_depth=6.........................
# [CV 1/5; 10/30] END learning_rate=0.0575, max_depth=6;, score=(train=0.887, test=0.872) total time=   0.3s
# [CV 1/5; 13/30] START learning_rate=0.105, max_depth=1..........................
# [CV 1/5; 13/30] END learning_rate=0.105, max_depth=1;, score=(train=0.819, test=0.815) total time=   0.1s
# [CV 2/5; 13/30] START learning_rate=0.105, max_depth=1..........................
# [CV 4/5; 12/30] END learning_rate=0.0575, max_depth=10;, score=(train=0.893, test=0.862) total time=   0.4s
# [CV 5/5; 12/30] START learning_rate=0.0575, max_depth=10........................
# [CV 2/5; 13/30] END learning_rate=0.105, max_depth=1;, score=(train=0.821, test=0.808) total time=   0.1s
# [CV 3/5; 13/30] START learning_rate=0.105, max_depth=1..........................
# [CV 2/5; 12/30] END learning_rate=0.0575, max_depth=10;, score=(train=0.889, test=0.872) total time=   0.4s
# [CV 3/5; 12/30] START learning_rate=0.0575, max_depth=10........................
# [CV 3/5; 10/30] END learning_rate=0.0575, max_depth=6;, score=(train=0.885, test=0.881) total time=   0.5s
# [CV 5/5; 13/30] START learning_rate=0.105, max_depth=1..........................
# [CV 5/5; 10/30] END learning_rate=0.0575, max_depth=6;, score=(train=0.887, test=0.874) total time=   0.3s
# [CV 2/5; 14/30] START learning_rate=0.105, max_depth=2..........................
# [CV 1/5; 11/30] END learning_rate=0.0575, max_depth=8;, score=(train=0.888, test=0.874) total time=   0.5s
# [CV 2/5; 11/30] START learning_rate=0.0575, max_depth=8.........................
# [CV 3/5; 13/30] END learning_rate=0.105, max_depth=1;, score=(train=0.816, test=0.827) total time=   0.1s
# [CV 4/5; 13/30] START learning_rate=0.105, max_depth=1..........................
# [CV 3/5; 11/30] END learning_rate=0.0575, max_depth=8;, score=(train=0.888, test=0.882) total time=   0.5s
# [CV 4/5; 11/30] START learning_rate=0.0575, max_depth=8.........................
# [CV 5/5; 11/30] END learning_rate=0.0575, max_depth=8;, score=(train=0.889, test=0.876) total time=   0.5s
# [CV 1/5; 12/30] START learning_rate=0.0575, max_depth=10........................
# [CV 5/5; 13/30] END learning_rate=0.105, max_depth=1;, score=(train=0.819, test=0.824) total time=   0.1s
# [CV 1/5; 14/30] START learning_rate=0.105, max_depth=2..........................
# [CV 4/5; 13/30] END learning_rate=0.105, max_depth=1;, score=(train=0.823, test=0.807) total time=   0.1s
# [CV 4/5; 14/30] START learning_rate=0.105, max_depth=2..........................
# [CV 2/5; 14/30] END learning_rate=0.105, max_depth=2;, score=(train=0.856, test=0.846) total time=   0.1s
# [CV 3/5; 14/30] START learning_rate=0.105, max_depth=2..........................
# [CV 4/5; 14/30] END learning_rate=0.105, max_depth=2;, score=(train=0.858, test=0.837) total time=   0.1s
# [CV 5/5; 14/30] START learning_rate=0.105, max_depth=2..........................
# [CV 1/5; 14/30] END learning_rate=0.105, max_depth=2;, score=(train=0.855, test=0.850) total time=   0.1s
# [CV 1/5; 15/30] START learning_rate=0.105, max_depth=4..........................
# [CV 5/5; 12/30] END learning_rate=0.0575, max_depth=10;, score=(train=0.890, test=0.876) total time=   0.3s
# [CV 3/5; 15/30] START learning_rate=0.105, max_depth=4..........................
# [CV 3/5; 14/30] END learning_rate=0.105, max_depth=2;, score=(train=0.852, test=0.858) total time=   0.1s
# [CV 5/5; 15/30] START learning_rate=0.105, max_depth=4..........................
# [CV 5/5; 14/30] END learning_rate=0.105, max_depth=2;, score=(train=0.854, test=0.854) total time=   0.2s
# [CV 2/5; 16/30] START learning_rate=0.105, max_depth=6..........................
# [CV 3/5; 12/30] END learning_rate=0.0575, max_depth=10;, score=(train=0.889, test=0.880) total time=   0.5s
# [CV 4/5; 16/30] START learning_rate=0.105, max_depth=6..........................
# [CV 1/5; 15/30] END learning_rate=0.105, max_depth=4;, score=(train=0.882, test=0.871) total time=   0.2s
# [CV 2/5; 15/30] START learning_rate=0.105, max_depth=4..........................
# [CV 3/5; 15/30] END learning_rate=0.105, max_depth=4;, score=(train=0.879, test=0.877) total time=   0.3s
# [CV 4/5; 15/30] START learning_rate=0.105, max_depth=4..........................
# [CV 2/5; 11/30] END learning_rate=0.0575, max_depth=8;, score=(train=0.890, test=0.872) total time=   0.5s
# [CV 1/5; 17/30] START learning_rate=0.105, max_depth=8..........................
# [CV 5/5; 15/30] END learning_rate=0.105, max_depth=4;, score=(train=0.881, test=0.871) total time=   0.3s
# [CV 1/5; 16/30] START learning_rate=0.105, max_depth=6..........................
# [CV 4/5; 11/30] END learning_rate=0.0575, max_depth=8;, score=(train=0.892, test=0.861) total time=   0.5s
# [CV 3/5; 17/30] START learning_rate=0.105, max_depth=8..........................
# [CV 1/5; 12/30] END learning_rate=0.0575, max_depth=10;, score=(train=0.890, test=0.874) total time=   0.6s
# [CV 5/5; 17/30] START learning_rate=0.105, max_depth=8..........................
# [CV 4/5; 15/30] END learning_rate=0.105, max_depth=4;, score=(train=0.885, test=0.855) total time=   0.2s
# [CV 2/5; 18/30] START learning_rate=0.105, max_depth=10.........................
# [CV 2/5; 15/30] END learning_rate=0.105, max_depth=4;, score=(train=0.882, test=0.868) total time=   0.2s
# [CV 4/5; 18/30] START learning_rate=0.105, max_depth=10.........................
# [CV 2/5; 16/30] END learning_rate=0.105, max_depth=6;, score=(train=0.894, test=0.873) total time=   0.3s
# [CV 3/5; 16/30] START learning_rate=0.105, max_depth=6..........................
# [CV 4/5; 16/30] END learning_rate=0.105, max_depth=6;, score=(train=0.897, test=0.861) total time=   0.4s
# [CV 5/5; 16/30] START learning_rate=0.105, max_depth=6..........................
# [CV 1/5; 16/30] END learning_rate=0.105, max_depth=6;, score=(train=0.894, test=0.876) total time=   0.3s
# [CV 1/5; 19/30] START learning_rate=0.15250000000000002, max_depth=1............
# [CV 2/5; 18/30] END learning_rate=0.105, max_depth=10;, score=(train=0.891, test=0.871) total time=   0.2s
# [CV 3/5; 18/30] START learning_rate=0.105, max_depth=10.........................
# [CV 1/5; 19/30] END learning_rate=0.15250000000000002, max_depth=1;, score=(train=0.827, test=0.824) total time=   0.1s
# [CV 2/5; 19/30] START learning_rate=0.15250000000000002, max_depth=1............
# [CV 1/5; 17/30] END learning_rate=0.105, max_depth=8;, score=(train=0.896, test=0.873) total time=   0.5s
# [CV 2/5; 17/30] START learning_rate=0.105, max_depth=8..........................
# [CV 3/5; 16/30] END learning_rate=0.105, max_depth=6;, score=(train=0.890, test=0.882) total time=   0.3s
# [CV 3/5; 19/30] START learning_rate=0.15250000000000002, max_depth=1............
# [CV 2/5; 19/30] END learning_rate=0.15250000000000002, max_depth=1;, score=(train=0.828, test=0.817) total time=   0.1s
# [CV 5/5; 19/30] START learning_rate=0.15250000000000002, max_depth=1............
# [CV 3/5; 17/30] END learning_rate=0.105, max_depth=8;, score=(train=0.896, test=0.883) total time=   0.5s
# [CV 4/5; 17/30] START learning_rate=0.105, max_depth=8..........................
# [CV 5/5; 17/30] END learning_rate=0.105, max_depth=8;, score=(train=0.897, test=0.877) total time=   0.5s
# [CV 1/5; 18/30] START learning_rate=0.105, max_depth=10.........................
# [CV 4/5; 18/30] END learning_rate=0.105, max_depth=10;, score=(train=0.901, test=0.863) total time=   0.4s
# [CV 5/5; 18/30] START learning_rate=0.105, max_depth=10.........................
# [CV 3/5; 19/30] END learning_rate=0.15250000000000002, max_depth=1;, score=(train=0.825, test=0.836) total time=   0.1s
# [CV 4/5; 19/30] START learning_rate=0.15250000000000002, max_depth=1............
# [CV 5/5; 19/30] END learning_rate=0.15250000000000002, max_depth=1;, score=(train=0.826, test=0.831) total time=   0.1s
# [CV 1/5; 20/30] START learning_rate=0.15250000000000002, max_depth=2............
# [CV 4/5; 19/30] END learning_rate=0.15250000000000002, max_depth=1;, score=(train=0.830, test=0.812) total time=   0.1s
# [CV 2/5; 20/30] START learning_rate=0.15250000000000002, max_depth=2............
# [CV 5/5; 16/30] END learning_rate=0.105, max_depth=6;, score=(train=0.894, test=0.876) total time=   0.4s
# [CV 3/5; 18/30] END learning_rate=0.105, max_depth=10;, score=(train=0.898, test=0.883) total time=   0.4s
# [CV 4/5; 20/30] START learning_rate=0.15250000000000002, max_depth=2............
# [CV 1/5; 21/30] START learning_rate=0.15250000000000002, max_depth=4............
# [CV 1/5; 20/30] END learning_rate=0.15250000000000002, max_depth=2;, score=(train=0.860, test=0.854) total time=   0.1s
# [CV 3/5; 21/30] START learning_rate=0.15250000000000002, max_depth=4............
# [CV 2/5; 20/30] END learning_rate=0.15250000000000002, max_depth=2;, score=(train=0.860, test=0.851) total time=   0.1s
# [CV 3/5; 20/30] START learning_rate=0.15250000000000002, max_depth=2............
# [CV 5/5; 18/30] END learning_rate=0.105, max_depth=10;, score=(train=0.894, test=0.874) total time=   0.3s
# [CV 5/5; 21/30] START learning_rate=0.15250000000000002, max_depth=4............
# [CV 4/5; 20/30] END learning_rate=0.15250000000000002, max_depth=2;, score=(train=0.863, test=0.840) total time=   0.2s
# [CV 5/5; 20/30] START learning_rate=0.15250000000000002, max_depth=2............
# [CV 3/5; 20/30] END learning_rate=0.15250000000000002, max_depth=2;, score=(train=0.859, test=0.861) total time=   0.1s
# [CV 2/5; 22/30] START learning_rate=0.15250000000000002, max_depth=6............
# [CV 1/5; 21/30] END learning_rate=0.15250000000000002, max_depth=4;, score=(train=0.885, test=0.873) total time=   0.2s
# [CV 2/5; 21/30] START learning_rate=0.15250000000000002, max_depth=4............
# [CV 3/5; 21/30] END learning_rate=0.15250000000000002, max_depth=4;, score=(train=0.883, test=0.878) total time=   0.2s
# [CV 4/5; 21/30] START learning_rate=0.15250000000000002, max_depth=4............
# [CV 2/5; 17/30] END learning_rate=0.105, max_depth=8;, score=(train=0.897, test=0.874) total time=   0.5s
# [CV 4/5; 22/30] START learning_rate=0.15250000000000002, max_depth=6............
# [CV 4/5; 17/30] END learning_rate=0.105, max_depth=8;, score=(train=0.900, test=0.861) total time=   0.5s
# [CV 1/5; 23/30] START learning_rate=0.15250000000000002, max_depth=8............
# [CV 5/5; 21/30] END learning_rate=0.15250000000000002, max_depth=4;, score=(train=0.887, test=0.872) total time=   0.2s
# [CV 1/5; 22/30] START learning_rate=0.15250000000000002, max_depth=6............
# [CV 1/5; 18/30] END learning_rate=0.105, max_depth=10;, score=(train=0.899, test=0.874) total time=   0.5s
# [CV 3/5; 23/30] START learning_rate=0.15250000000000002, max_depth=8............
# [CV 5/5; 20/30] END learning_rate=0.15250000000000002, max_depth=2;, score=(train=0.861, test=0.859) total time=   0.2s
# [CV 5/5; 23/30] START learning_rate=0.15250000000000002, max_depth=8............
# [CV 2/5; 21/30] END learning_rate=0.15250000000000002, max_depth=4;, score=(train=0.886, test=0.867) total time=   0.2s
# [CV 2/5; 24/30] START learning_rate=0.15250000000000002, max_depth=10...........
# [CV 4/5; 21/30] END learning_rate=0.15250000000000002, max_depth=4;, score=(train=0.889, test=0.857) total time=   0.2s
# [CV 4/5; 24/30] START learning_rate=0.15250000000000002, max_depth=10...........
# [CV 2/5; 22/30] END learning_rate=0.15250000000000002, max_depth=6;, score=(train=0.899, test=0.874) total time=   0.3s
# [CV 3/5; 22/30] START learning_rate=0.15250000000000002, max_depth=6............
# [CV 1/5; 22/30] END learning_rate=0.15250000000000002, max_depth=6;, score=(train=0.900, test=0.876) total time=   0.3s
# [CV 1/5; 25/30] START learning_rate=0.2, max_depth=1............................
# [CV 3/5; 23/30] END learning_rate=0.15250000000000002, max_depth=8;, score=(train=0.893, test=0.882) total time=   0.3s
# [CV 4/5; 23/30] START learning_rate=0.15250000000000002, max_depth=8............
# [CV 4/5; 22/30] END learning_rate=0.15250000000000002, max_depth=6;, score=(train=0.901, test=0.862) total time=   0.4s
# [CV 5/5; 22/30] START learning_rate=0.15250000000000002, max_depth=6............
# [CV 2/5; 24/30] END learning_rate=0.15250000000000002, max_depth=10;, score=(train=0.900, test=0.875) total time=   0.3s
# [CV 3/5; 24/30] START learning_rate=0.15250000000000002, max_depth=10...........
# [CV 1/5; 23/30] END learning_rate=0.15250000000000002, max_depth=8;, score=(train=0.899, test=0.874) total time=   0.4s
# [CV 2/5; 23/30] START learning_rate=0.15250000000000002, max_depth=8............
# [CV 1/5; 25/30] END learning_rate=0.2, max_depth=1;, score=(train=0.831, test=0.825) total time=   0.1s
# [CV 2/5; 25/30] START learning_rate=0.2, max_depth=1............................
# [CV 4/5; 24/30] END learning_rate=0.15250000000000002, max_depth=10;, score=(train=0.904, test=0.864) total time=   0.3s
# [CV 5/5; 24/30] START learning_rate=0.15250000000000002, max_depth=10...........
# [CV 2/5; 25/30] END learning_rate=0.2, max_depth=1;, score=(train=0.831, test=0.820) total time=   0.1s
# [CV 3/5; 25/30] START learning_rate=0.2, max_depth=1............................
# [CV 5/5; 23/30] END learning_rate=0.15250000000000002, max_depth=8;, score=(train=0.901, test=0.877) total time=   0.5s
# [CV 1/5; 24/30] START learning_rate=0.15250000000000002, max_depth=10...........
# [CV 3/5; 22/30] END learning_rate=0.15250000000000002, max_depth=6;, score=(train=0.898, test=0.884) total time=   0.3s
# [CV 5/5; 25/30] START learning_rate=0.2, max_depth=1............................
# [CV 3/5; 25/30] END learning_rate=0.2, max_depth=1;, score=(train=0.829, test=0.839) total time=   0.1s
# [CV 4/5; 25/30] START learning_rate=0.2, max_depth=1............................
# [CV 5/5; 25/30] END learning_rate=0.2, max_depth=1;, score=(train=0.830, test=0.834) total time=   0.1s
# [CV 1/5; 26/30] START learning_rate=0.2, max_depth=2............................
# [CV 4/5; 23/30] END learning_rate=0.15250000000000002, max_depth=8;, score=(train=0.901, test=0.861) total time=   0.4s
# [CV 2/5; 26/30] START learning_rate=0.2, max_depth=2............................
# [CV 4/5; 25/30] END learning_rate=0.2, max_depth=1;, score=(train=0.833, test=0.815) total time=   0.1s
# [CV 4/5; 26/30] START learning_rate=0.2, max_depth=2............................
# [CV 5/5; 24/30] END learning_rate=0.15250000000000002, max_depth=10;, score=(train=0.901, test=0.878) total time=   0.3s
# [CV 1/5; 27/30] START learning_rate=0.2, max_depth=4............................
# [CV 3/5; 24/30] END learning_rate=0.15250000000000002, max_depth=10;, score=(train=0.903, test=0.882) total time=   0.3s
# [CV 3/5; 27/30] START learning_rate=0.2, max_depth=4............................
# [CV 5/5; 22/30] END learning_rate=0.15250000000000002, max_depth=6;, score=(train=0.899, test=0.876) total time=   0.4s
# [CV 5/5; 27/30] START learning_rate=0.2, max_depth=4............................
# [CV 1/5; 26/30] END learning_rate=0.2, max_depth=2;, score=(train=0.864, test=0.859) total time=   0.1s
# [CV 2/5; 28/30] START learning_rate=0.2, max_depth=6............................
# [CV 2/5; 23/30] END learning_rate=0.15250000000000002, max_depth=8;, score=(train=0.901, test=0.874) total time=   0.4s
# [CV 4/5; 28/30] START learning_rate=0.2, max_depth=6............................
# [CV 4/5; 26/30] END learning_rate=0.2, max_depth=2;, score=(train=0.867, test=0.844) total time=   0.1s
# [CV 5/5; 26/30] START learning_rate=0.2, max_depth=2............................
# [CV 2/5; 26/30] END learning_rate=0.2, max_depth=2;, score=(train=0.865, test=0.855) total time=   0.1s
# [CV 3/5; 26/30] START learning_rate=0.2, max_depth=2............................
# [CV 1/5; 27/30] END learning_rate=0.2, max_depth=4;, score=(train=0.890, test=0.872) total time=   0.2s
# [CV 2/5; 27/30] START learning_rate=0.2, max_depth=4............................
# [CV 3/5; 27/30] END learning_rate=0.2, max_depth=4;, score=(train=0.887, test=0.880) total time=   0.2s
# [CV 4/5; 27/30] START learning_rate=0.2, max_depth=4............................
# [CV 5/5; 26/30] END learning_rate=0.2, max_depth=2;, score=(train=0.864, test=0.861) total time=   0.1s
# [CV 1/5; 29/30] START learning_rate=0.2, max_depth=8............................
# [CV 2/5; 28/30] END learning_rate=0.2, max_depth=6;, score=(train=0.898, test=0.874) total time=   0.2s
# [CV 3/5; 28/30] START learning_rate=0.2, max_depth=6............................
# [CV 1/5; 24/30] END learning_rate=0.15250000000000002, max_depth=10;, score=(train=0.905, test=0.877) total time=   0.5s
# [CV 3/5; 29/30] START learning_rate=0.2, max_depth=8............................
# [CV 5/5; 27/30] END learning_rate=0.2, max_depth=4;, score=(train=0.890, test=0.873) total time=   0.3s
# [CV 1/5; 28/30] START learning_rate=0.2, max_depth=6............................
# [CV 3/5; 26/30] END learning_rate=0.2, max_depth=2;, score=(train=0.861, test=0.864) total time=   0.2s
# [CV 5/5; 29/30] START learning_rate=0.2, max_depth=8............................
# [CV 1/5; 29/30] END learning_rate=0.2, max_depth=8;, score=(train=0.893, test=0.875) total time=   0.1s
# [CV 2/5; 29/30] START learning_rate=0.2, max_depth=8............................
# [CV 4/5; 27/30] END learning_rate=0.2, max_depth=4;, score=(train=0.892, test=0.859) total time=   0.2s
# [CV 1/5; 30/30] START learning_rate=0.2, max_depth=10...........................
# [CV 2/5; 27/30] END learning_rate=0.2, max_depth=4;, score=(train=0.889, test=0.870) total time=   0.2s
# [CV 2/5; 30/30] START learning_rate=0.2, max_depth=10...........................
# [CV 4/5; 28/30] END learning_rate=0.2, max_depth=6;, score=(train=0.906, test=0.863) total time=   0.4s
# [CV 5/5; 28/30] START learning_rate=0.2, max_depth=6............................
# [CV 3/5; 28/30] END learning_rate=0.2, max_depth=6;, score=(train=0.899, test=0.883) total time=   0.2s
# [CV 3/5; 30/30] START learning_rate=0.2, max_depth=10...........................
# [CV 2/5; 29/30] END learning_rate=0.2, max_depth=8;, score=(train=0.898, test=0.875) total time=   0.2s
# [CV 4/5; 30/30] START learning_rate=0.2, max_depth=10...........................
# [CV 2/5; 30/30] END learning_rate=0.2, max_depth=10;, score=(train=0.901, test=0.875) total time=   0.2s
# [CV 5/5; 30/30] START learning_rate=0.2, max_depth=10...........................
# [CV 3/5; 29/30] END learning_rate=0.2, max_depth=8;, score=(train=0.901, test=0.881) total time=   0.4s
# [CV 4/5; 29/30] START learning_rate=0.2, max_depth=8............................
# [CV 1/5; 30/30] END learning_rate=0.2, max_depth=10;, score=(train=0.905, test=0.873) total time=   0.3s
# [CV 1/5; 28/30] END learning_rate=0.2, max_depth=6;, score=(train=0.903, test=0.876) total time=   0.4s
# [CV 3/5; 30/30] END learning_rate=0.2, max_depth=10;, score=(train=0.898, test=0.879) total time=   0.2s
# [CV 5/5; 28/30] END learning_rate=0.2, max_depth=6;, score=(train=0.896, test=0.879) total time=   0.3s
# [CV 5/5; 29/30] END learning_rate=0.2, max_depth=8;, score=(train=0.908, test=0.874) total time=   0.5s
# [CV 4/5; 30/30] END learning_rate=0.2, max_depth=10;, score=(train=0.905, test=0.862) total time=   0.2s
# [CV 4/5; 29/30] END learning_rate=0.2, max_depth=8;, score=(train=0.903, test=0.862) total time=   0.2s
# [CV 5/5; 30/30] END learning_rate=0.2, max_depth=10;, score=(train=0.909, test=0.876) total time=   0.3s
# GridSearchCV(estimator=HistGradientBoostingRegressor(), n_jobs=8,
#              param_grid={'learning_rate': array([0.01  , 0.0575, 0.105 , 0.1525, 0.2   ]),
#                          'max_depth': [1, 2, 4, 6, 8, 10]},
#              return_train_score=True, verbose=10)

# %%
results = gridsearch.cv_results_

train_score = results['mean_train_score'][gridsearch.best_index_]
validation_score = results['mean_test_score'][gridsearch.best_index_]

print('Training accuracy {}'.format(train_score))
print('Validation accuracy: {}'.format(validation_score))

print('Best estimator:')
print(gridsearch.best_estimator_)
# Out:
# Training accuracy 0.9029007633967104
# Validation accuracy: 0.875328509598497
# Best estimator:
# HistGradientBoostingRegressor(learning_rate=0.15250000000000002, max_depth=10)

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

def plot_grid_search(cv_results, grid_param_1, grid_param_2, name_param_1, name_param_2, type='train'):
    # Get Test Scores Mean and std for each grid search
    scores_mean = cv_results[f'mean_{type}_score']
    scores_mean = np.array(scores_mean).reshape(len(grid_param_2),len(grid_param_1))
    print(scores_mean)

    _, ax = plt.subplots(1,1)
    ax.pcolor(scores_mean)
    ax.set_title(f"Grid Search Scores {type}", fontsize=20, fontweight='bold')
    ax.set_xlabel(name_param_1, fontsize=16)
    ax.set_ylabel(name_param_2, fontsize=16)
    ax.set_xticklabels(grid_param_1)
    ax.set_yticklabels(grid_param_2)


    scores_sd = cv_results[f'std_{type}_score']
    scores_sd = np.array(scores_sd).reshape(len(grid_param_2),len(grid_param_1))

    # Plot Grid search scores
    _, ax = plt.subplots(1,1)

    # Param1 is the X-axis, Param 2 is represented as a different curve (color line)
    for idx, val in enumerate(grid_param_2):
        ax.plot(grid_param_1, scores_mean[idx,:], '-o', label= name_param_2 + ': ' + str(val))

    ax.set_title(f"Grid Search Scores {type}", fontsize=20, fontweight='bold')
    ax.set_xlabel(name_param_1, fontsize=16)
    ax.set_ylabel('CV Average Score', fontsize=16)
    ax.legend(loc="best", fontsize=15)
    ax.grid('on')

# Calling Method 
# plot_grid_search(gridsearch.cv_results_, param_grid['max_depth'], param_grid['learning_rate'], 'd', 'l', 'train')
plot_grid_search(gridsearch.cv_results_, param_grid['max_depth'], param_grid['learning_rate'], 'd', 'l', 'test')
plt.show()
# Out:
# [[0.53518094 0.64741989 0.71525146 0.73735322 0.73886463 0.73831643]
#  [0.78896706 0.83751535 0.86286518 0.87148717 0.87293037 0.87294057]
#  [0.81653519 0.84917844 0.86820598 0.87364828 0.8735846  0.87320545]
#  [0.82375177 0.85312771 0.86941512 0.87450739 0.87354427 0.87532851]
#  [0.82652332 0.85657374 0.87089827 0.87480604 0.87322154 0.87295718]]
# /tmp/ipykernel_31479/1126520658.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(grid_param_1)
# /tmp/ipykernel_31479/1126520658.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(grid_param_2)

# %%
def plot_learning_curve(sizes,train,val):
    train_scores_mean = np.mean(train, axis=1)
    train_scores_std = np.std(train, axis=1)
    val_scores_mean = np.mean(val, axis=1)
    val_scores_std = np.std(val, axis=1)

    _, axes = plt.subplots(1,)
    axes.grid()
    axes.fill_between(
        sizes,
        train_scores_mean - train_scores_std,
        train_scores_mean + train_scores_std,
        alpha=0.1,
        color="g",
    )
    axes.fill_between(
        sizes,
        val_scores_mean - val_scores_std,
        val_scores_mean + val_scores_std,
        alpha=0.1,
        color="r",
    )
    axes.plot(
        sizes, train_scores_mean, "o-", color="g", label="Training score"
    )
    axes.plot(
        sizes, val_scores_mean, "o-", color="r", label="Cross-validation score"
    )
    axes.set_ylim((0,1))
    axes.legend(loc="best")
    
    plt.show()
    return

# %%
from sklearn.model_selection import learning_curve

train_sizes, train_scores, val_scores = learning_curve(gridsearch.best_estimator_, X, y.to_numpy()[:, 0], n_jobs=4, verbose=5)
plot_learning_curve(train_sizes, train_scores, val_scores)
# Out:
# [learning_curve] Training set sizes: [ 1482  4817  8152 11487 14822]
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [CV] END ..................., score=(train=0.673, test=0.102) total time=   0.2s
# [CV] END ..................., score=(train=0.584, test=0.082) total time=   0.3s
# [CV] END ..................., score=(train=0.944, test=0.144) total time=   0.3s
# [Parallel(n_jobs=4)]: Done   2 out of  25 | elapsed:    1.1s remaining:   12.3s
# [CV] END ..................., score=(train=0.936, test=0.199) total time=   0.4s
# [CV] END ..................., score=(train=0.287, test=0.006) total time=   0.2s
# [CV] END ..................., score=(train=0.921, test=0.175) total time=   0.4s
# [CV] END .................., score=(train=0.676, test=-0.409) total time=   0.3s
# [CV] END .................., score=(train=0.936, test=-0.323) total time=   0.3s
# [Parallel(n_jobs=4)]: Done   8 out of  25 | elapsed:    1.6s remaining:    3.5s
# [CV] END .................., score=(train=0.945, test=-0.714) total time=   0.4s
# [CV] END .................., score=(train=0.287, test=-0.334) total time=   0.2s
# [CV] END .................., score=(train=0.918, test=-0.245) total time=   0.3s
# [CV] END ..................., score=(train=0.669, test=0.268) total time=   0.3s
# [CV] END ..................., score=(train=0.858, test=0.866) total time=   0.3s
# [CV] END ..................., score=(train=0.854, test=0.865) total time=   0.4s
# [CV] END .................., score=(train=0.287, test=-0.043) total time=   0.2s
# [Parallel(n_jobs=4)]: Done  14 out of  25 | elapsed:    2.1s remaining:    1.7s
# [CV] END ..................., score=(train=0.833, test=0.866) total time=   0.3s
# [CV] END .................., score=(train=0.669, test=-0.665) total time=   0.3s
# [CV] END .................., score=(train=0.579, test=-0.653) total time=   0.3s
# [CV] END .................., score=(train=0.909, test=-0.516) total time=   0.3s
# [CV] END .................., score=(train=0.287, test=-0.012) total time=   0.2s
# [CV] END ..................., score=(train=0.890, test=0.371) total time=   0.3s
# [Parallel(n_jobs=4)]: Done  20 out of  25 | elapsed:    2.6s remaining:    0.6s
# [CV] END .................., score=(train=0.669, test=-0.458) total time=   0.3s
# [CV] END .................., score=(train=0.579, test=-0.255) total time=   0.3s
# [CV] END .................., score=(train=0.918, test=-0.406) total time=   0.3s
# [CV] END ..................., score=(train=0.916, test=0.193) total time=   0.3s
# [Parallel(n_jobs=4)]: Done  25 out of  25 | elapsed:    3.0s finished

# %%
gridsearch.best_estimator_.score(X_test, y_test)
# Out:
# 0.8852337094637003

# %%
Y_pred = gridsearch.best_estimator_.predict(X_test)

# %%
plt.plot(combined['F_x'], label='true')
plt.plot(gridsearch.best_estimator_.predict(X), label='pred')
# plt.xlim((6000, 8000))
# Out:
# /home/lowiek/.local/lib/python3.10/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but HistGradientBoostingRegressor was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ## Creating a model for each component

# %%
regressors = []
columns = ['F_x', 'F_y', 'F_z']
for col in columns:
  
  # (Train/val) / test split
  X = combined[['X', 'Y', 'Z', 'sens_magnitude', 'sens_magnitude_XY']][1:]
  y = combined[[col]][1:]

  X_train, X_test, y_train, y_test = train_test_split(X.to_numpy(), y.to_numpy(), test_size=0.2, shuffle=True)

  reg = HistGradientBoostingRegressor()

  gridsearch = GridSearchCV(reg, param_grid=param_grid, verbose=1, return_train_score=True, n_jobs=8)

  gridsearch.fit(X_train, y_train[:, 0])  
  
  print("Score: ", gridsearch.best_estimator_.score(X_test, y_test))
  
  regressors.append(gridsearch.best_estimator_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Score:  0.8823521530781029
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Score:  0.9657852869358504
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Score:  0.9840017295558416

# %%
print(regressors)
# Out:
# [HistGradientBoostingRegressor(learning_rate=0.15250000000000002, max_depth=10), HistGradientBoostingRegressor(learning_rate=0.15250000000000002, max_depth=10), HistGradientBoostingRegressor(learning_rate=0.2, max_depth=10)]

# %%
predictions = []
for reg in regressors:
  predictions.append(reg.predict(X)) 
  
print(np.array(predictions))
plot_predictions(np.array(predictions).T, combined[['F_x','F_y','F_z']].to_numpy())
# Out:
# /home/lowiek/.local/lib/python3.10/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but HistGradientBoostingRegressor was fitted without feature names
#   warnings.warn(
# /home/lowiek/.local/lib/python3.10/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but HistGradientBoostingRegressor was fitted without feature names
#   warnings.warn(
# /home/lowiek/.local/lib/python3.10/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but HistGradientBoostingRegressor was fitted without feature names
#   warnings.warn(
# [[ 0.01665536  0.0213368   0.04154339 ...  0.00780502  0.00780502
#    0.00780502]
#  [-0.05200741 -0.03210952 -0.0516513  ... -0.06185914 -0.06185914
#   -0.06185914]
#  [ 0.08887509  0.09581947  0.08219972 ...  0.04225369  0.04225369
#    0.04225369]]

# %%
index = 1
letter = 'F_y'

plt.plot(combined[letter].to_numpy(), label='true')
plt.plot((np.array(predictions).T)[:, index], label='pred')
plt.legend()
# plt.xlim((11000, 15000))

# %%
import pickle

# Save the models to the folder
save_path = os.path.join(os.getcwd(), 'models', 'H1_5_sensor' + str(TAXEL_INDEX))

for col, reg in zip(columns, regressors):
  with open(os.path.join(save_path, col), 'wb') as f:
    pickle.dump(reg, f)

# %% [markdown]
# # MLPRegressor

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neural_network import MLPRegressor

# %%
X = combined[['X', 'Y', 'Z', 'sens_magnitude', 'sens_magnitude_XY']][1:]
y = combined[['F_x', 'F_y', 'F_z']][1:]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1
)

reg = MLPRegressor(hidden_layer_sizes=(100, 50), max_iter=10000, activation='relu', solver='adam', verbose=True)
reg.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.28868041
# Iteration 2, loss = 0.14084119
# Iteration 3, loss = 0.11852400
# Iteration 4, loss = 0.10613001
# Iteration 5, loss = 0.09729583
# Iteration 6, loss = 0.09122093
# Iteration 7, loss = 0.08840173
# Iteration 8, loss = 0.08738685
# Iteration 9, loss = 0.08352604
# Iteration 10, loss = 0.08187886
# Iteration 11, loss = 0.08012806
# Iteration 12, loss = 0.07984469
# Iteration 13, loss = 0.07807515
# Iteration 14, loss = 0.07646950
# Iteration 15, loss = 0.07516233
# Iteration 16, loss = 0.07458835
# Iteration 17, loss = 0.07275754
# Iteration 18, loss = 0.07286851
# Iteration 19, loss = 0.07211271
# Iteration 20, loss = 0.07192180
# Iteration 21, loss = 0.07094516
# Iteration 22, loss = 0.07033484
# Iteration 23, loss = 0.07088318
# Iteration 24, loss = 0.06902426
# Iteration 25, loss = 0.06806351
# Iteration 26, loss = 0.06704338
# Iteration 27, loss = 0.06601536
# Iteration 28, loss = 0.06682761
# Iteration 29, loss = 0.06380340
# Iteration 30, loss = 0.06372623
# Iteration 31, loss = 0.06319346
# Iteration 32, loss = 0.06244397
# Iteration 33, loss = 0.06268101
# Iteration 34, loss = 0.06175223
# Iteration 35, loss = 0.06179389
# Iteration 36, loss = 0.06176870
# Iteration 37, loss = 0.06172242
# Iteration 38, loss = 0.06159516
# Iteration 39, loss = 0.06005400
# Iteration 40, loss = 0.06084833
# Iteration 41, loss = 0.06087245
# Iteration 42, loss = 0.06142895
# Iteration 43, loss = 0.06290216
# Iteration 44, loss = 0.06167721
# Iteration 45, loss = 0.05971604
# Iteration 46, loss = 0.06024967
# Iteration 47, loss = 0.05957279
# Iteration 48, loss = 0.05919786
# Iteration 49, loss = 0.05679935
# Iteration 50, loss = 0.05934667
# Iteration 51, loss = 0.05798523
# Iteration 52, loss = 0.05817406
# Iteration 53, loss = 0.05694371
# Iteration 54, loss = 0.05819047
# Iteration 55, loss = 0.05882506
# Iteration 56, loss = 0.05786203
# Iteration 57, loss = 0.05626750
# Iteration 58, loss = 0.05559176
# Iteration 59, loss = 0.05551941
# Iteration 60, loss = 0.05911408
# Iteration 61, loss = 0.05602935
# Iteration 62, loss = 0.05593077
# Iteration 63, loss = 0.05777558
# Iteration 64, loss = 0.05693350
# Iteration 65, loss = 0.05345755
# Iteration 66, loss = 0.05462904
# Iteration 67, loss = 0.05358847
# Iteration 68, loss = 0.05380854
# Iteration 69, loss = 0.05629978
# Iteration 70, loss = 0.05425061
# Iteration 71, loss = 0.05414859
# Iteration 72, loss = 0.05354952
# Iteration 73, loss = 0.05393583
# Iteration 74, loss = 0.05270696
# Iteration 75, loss = 0.05326356
# Iteration 76, loss = 0.05321119
# Iteration 77, loss = 0.05182866
# Iteration 78, loss = 0.05116020
# Iteration 79, loss = 0.05112590
# Iteration 80, loss = 0.05154247
# Iteration 81, loss = 0.05107294
# Iteration 82, loss = 0.05197867
# Iteration 83, loss = 0.05092767
# Iteration 84, loss = 0.05123206
# Iteration 85, loss = 0.05019693
# Iteration 86, loss = 0.05019430
# Iteration 87, loss = 0.05053476
# Iteration 88, loss = 0.05073110
# Iteration 89, loss = 0.05025620
# Iteration 90, loss = 0.05110895
# Iteration 91, loss = 0.04997253
# Iteration 92, loss = 0.05191947
# Iteration 93, loss = 0.04914867
# Iteration 94, loss = 0.04922132
# Iteration 95, loss = 0.04978322
# Iteration 96, loss = 0.04959308
# Iteration 97, loss = 0.04896364
# Iteration 98, loss = 0.04817005
# Iteration 99, loss = 0.04796241
# Iteration 100, loss = 0.04722025
# Iteration 101, loss = 0.04833746
# Iteration 102, loss = 0.04870943
# Iteration 103, loss = 0.04817521
# Iteration 104, loss = 0.05136887
# Iteration 105, loss = 0.05049359
# Iteration 106, loss = 0.04937176
# Iteration 107, loss = 0.05060851
# Iteration 108, loss = 0.04605664
# Iteration 109, loss = 0.04603033
# Iteration 110, loss = 0.04854678
# Iteration 111, loss = 0.04779120
# Iteration 112, loss = 0.04584622
# Iteration 113, loss = 0.04591497
# Iteration 114, loss = 0.04678602
# Iteration 115, loss = 0.04717860
# Iteration 116, loss = 0.04785001
# Iteration 117, loss = 0.04617815
# Iteration 118, loss = 0.04467043
# Iteration 119, loss = 0.04602949
# Iteration 120, loss = 0.04568397
# Iteration 121, loss = 0.04482796
# Iteration 122, loss = 0.04467939
# Iteration 123, loss = 0.04601996
# Iteration 124, loss = 0.04513789
# Iteration 125, loss = 0.04713597
# Iteration 126, loss = 0.04634352
# Iteration 127, loss = 0.04407752
# Iteration 128, loss = 0.04492133
# Iteration 129, loss = 0.04682853
# Iteration 130, loss = 0.04418571
# Iteration 131, loss = 0.04419362
# Iteration 132, loss = 0.04373560
# Iteration 133, loss = 0.04381670
# Iteration 134, loss = 0.04494263
# Iteration 135, loss = 0.04443933
# Iteration 136, loss = 0.04379144
# Iteration 137, loss = 0.04408115
# Iteration 138, loss = 0.04290378
# Iteration 139, loss = 0.04217711
# Iteration 140, loss = 0.04399030
# Iteration 141, loss = 0.04456795
# Iteration 142, loss = 0.04505005
# Iteration 143, loss = 0.04310508
# Iteration 144, loss = 0.04536912
# Iteration 145, loss = 0.04450847
# Iteration 146, loss = 0.04299722
# Iteration 147, loss = 0.04274555
# Iteration 148, loss = 0.04201582
# Iteration 149, loss = 0.04438982
# Iteration 150, loss = 0.04197612
# Iteration 151, loss = 0.04236756
# Iteration 152, loss = 0.04163737
# Iteration 153, loss = 0.04266245
# Iteration 154, loss = 0.04224862
# Iteration 155, loss = 0.04166576
# Iteration 156, loss = 0.04176465
# Iteration 157, loss = 0.04356765
# Iteration 158, loss = 0.04178422
# Iteration 159, loss = 0.04109836
# Iteration 160, loss = 0.04158303
# Iteration 161, loss = 0.04170108
# Iteration 162, loss = 0.04138483
# Iteration 163, loss = 0.04181425
# Iteration 164, loss = 0.04146313
# Iteration 165, loss = 0.04347863
# Iteration 166, loss = 0.04072126
# Iteration 167, loss = 0.04135516
# Iteration 168, loss = 0.04126142
# Iteration 169, loss = 0.04035057
# Iteration 170, loss = 0.04192823
# Iteration 171, loss = 0.04020502
# Iteration 172, loss = 0.04021694
# Iteration 173, loss = 0.04144458
# Iteration 174, loss = 0.04305888
# Iteration 175, loss = 0.04439622
# Iteration 176, loss = 0.04045805
# Iteration 177, loss = 0.04100804
# Iteration 178, loss = 0.04114136
# Iteration 179, loss = 0.04068008
# Iteration 180, loss = 0.04028165
# Iteration 181, loss = 0.04052087
# Iteration 182, loss = 0.03964813
# Iteration 183, loss = 0.03997149
# Iteration 184, loss = 0.04117269
# Iteration 185, loss = 0.03987700
# Iteration 186, loss = 0.03978934
# Iteration 187, loss = 0.04027411
# Iteration 188, loss = 0.03912166
# Iteration 189, loss = 0.04032761
# Iteration 190, loss = 0.03997653
# Iteration 191, loss = 0.03905480
# Iteration 192, loss = 0.03851835
# Iteration 193, loss = 0.03865257
# Iteration 194, loss = 0.03842899
# Iteration 195, loss = 0.03871408
# Iteration 196, loss = 0.03999164
# Iteration 197, loss = 0.04077099
# Iteration 198, loss = 0.04008562
# Iteration 199, loss = 0.04030764
# Iteration 200, loss = 0.03873210
# Iteration 201, loss = 0.04124931
# Iteration 202, loss = 0.03871487
# Iteration 203, loss = 0.03801179
# Iteration 204, loss = 0.03980074
# Iteration 205, loss = 0.03877874
# Iteration 206, loss = 0.03800573
# Iteration 207, loss = 0.03799715
# Iteration 208, loss = 0.04163640
# Iteration 209, loss = 0.03935313
# Iteration 210, loss = 0.04028300
# Iteration 211, loss = 0.03725703
# Iteration 212, loss = 0.03887080
# Iteration 213, loss = 0.03866208
# Iteration 214, loss = 0.03863433
# Iteration 215, loss = 0.03863105
# Iteration 216, loss = 0.03894359
# Iteration 217, loss = 0.03769160
# Iteration 218, loss = 0.03800501
# Iteration 219, loss = 0.03721961
# Iteration 220, loss = 0.03848128
# Iteration 221, loss = 0.04044957
# Iteration 222, loss = 0.03824264
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPRegressor(hidden_layer_sizes=(100, 50), max_iter=10000, verbose=True)

# %%
reg.score(X_test, y_test)
# Out:
# 0.8528971152029233

# %%
Y_pred = reg.predict(X)

# %%
plot_predictions(Y.to_numpy(), Y_pred)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/lowiek/masters-thesis/notebooks/single_taxel_calib.ipynb Cell 51 line 1
# ----> <a href='vscode-notebook-cell:/home/lowiek/masters-thesis/notebooks/single_taxel_calib.ipynb#Y124sZmlsZQ%3D%3D?line=0'>1</a> plot_predictions(Y.to_numpy(), Y_pred)
#
# /home/lowiek/masters-thesis/notebooks/single_taxel_calib.ipynb Cell 51 line 1
#       <a href='vscode-notebook-cell:/home/lowiek/masters-thesis/notebooks/single_taxel_calib.ipynb#Y124sZmlsZQ%3D%3D?line=7'>8</a>   plt.subplot(subplot_index + i)
#       <a href='vscode-notebook-cell:/home/lowiek/masters-thesis/notebooks/single_taxel_calib.ipynb#Y124sZmlsZQ%3D%3D?line=8'>9</a>   plt.plot(Y[:,i], label='true')
# ---> <a href='vscode-notebook-cell:/home/lowiek/masters-thesis/notebooks/single_taxel_calib.ipynb#Y124sZmlsZQ%3D%3D?line=9'>10</a>   plt.plot(Y_pred[:,i], label='pred')
#      <a href='vscode-notebook-cell:/home/lowiek/masters-thesis/notebooks/single_taxel_calib.ipynb#Y124sZmlsZQ%3D%3D?line=11'>12</a> plt.show()
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
index = 2

plt.plot(Y.to_numpy()[:, index], label='true')
plt.plot(Y_pred[:, index], label='pred')
plt.legend()
plt.xlim((6000,9000))
# Out:
# (6000.0, 9000.0)
