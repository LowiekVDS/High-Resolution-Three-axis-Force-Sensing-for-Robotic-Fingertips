# %% [markdown]
# # Model creation stage III (4x8)

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Setup

# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from tools import common_functions as cf
from tools import regression as reg
from tools import plotting_functions as pf

from tools import sensor_gui as sg

# Folder prefix with all the taxel data
TAXEL_DATA_FOLDER = f"table_calibration/silliconv2_taxel"


# Parameters
SENSOR_LAG = 110 # ms
ARRAY_SIZE = 32

# Automated
data_columns = [f'X{i}' for i in range(ARRAY_SIZE)] + [f'Y{i}' for i in range(ARRAY_SIZE)] + [f'Z{i}' for i in range(ARRAY_SIZE)]

# %%
taxels_data = []

for i in range(ARRAY_SIZE):
  if i == 22:
    taxels_data.append(None)
    continue
  # Load the data
  taxel_data = cf.prepare_data_for_fitting(f"{TAXEL_DATA_FOLDER}{i}", ARRAY_SIZE, SENSOR_LAG, rotation=90 + 1.82, faulty=False, cut_in_half=False)
  taxels_data.append(taxel_data)
# Out:
# Preparing data for fitting: table_calibration/silliconv2_taxel0
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel1
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel2
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel3
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel4
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel5
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel6
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel7
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel8
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel9
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel10
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel11
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel12
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel13
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel14
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel15
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel16
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel17
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel18
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel19
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel20
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel21
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel23
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel24
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel25
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel26
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel27
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel28
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel29
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel30
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])
# Preparing data for fitting: table_calibration/silliconv2_taxel31
# /home/lowiek/masters-thesis/notebooks/tools/common_functions.py:311: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   data[col] -= mean_without_outliers(data[col][:window])

# %%
# Load models from stage II
import os
import dill

save_path = os.path.join(os.getcwd(), '..', 'models', "4x8")
stage_II_model = dill.load(open(os.path.join(save_path, "stageII"), 'rb'))

# %%
stage_II_model.predict(taxels_data[0])
# Out:
# (array([[ 4.23330942e-03,  7.65372242e-04,  1.23200879e-02, ...,
#          -3.82323796e-02, -1.09188684e-01,  2.27347282e-04],
#         [ 4.37519356e-03, -3.49071044e-05,  1.26455284e-02, ...,
#          -3.81690850e-02, -1.10635961e-01,  6.45944852e-03],
#         [ 4.51694853e-03, -8.35310410e-04,  1.29701590e-02, ...,
#          -3.81061927e-02, -1.12083981e-01,  1.26943327e-02],
#         ...,
#         [ 7.67993178e-03, -6.34955923e-03, -1.71813208e-02, ...,
#          -7.03662004e-02, -1.28495798e-01,  6.37321984e-04],
#         [ 7.67993178e-03, -6.34955923e-03, -1.71813208e-02, ...,
#          -7.03662004e-02, -1.28495798e-01,  6.37321984e-04],
#         [ 7.67993178e-03, -6.34955923e-03, -1.71813208e-02, ...,
#          -7.03662004e-02, -1.28495798e-01,  6.37321984e-04]]),
#  array([[ 0.00075897, -0.00117368,  0.01907301, ..., -0.05381681,
#          -0.11226173, -0.02386856],
#         [ 0.00100122, -0.00207233,  0.01953534, ..., -0.05392716,
#          -0.1137027 , -0.01774547],
#         [ 0.00124355, -0.00297095,  0.01999731, ..., -0.05403786,
#          -0.11514408, -0.01161991],
#         ...,
#         [ 0.0048432 , -0.00945073, -0.01668593, ..., -0.0882247 ,
#          -0.13861607, -0.02364191],
#         [ 0.0048432 , -0.00945073, -0.01668593, ..., -0.0882247 ,
#          -0.13861607, -0.02364191],
#         [ 0.0048432 , -0.00945073, -0.01668593, ..., -0.0882247 ,
#          -0.13861607, -0.02364191]]))

# %% [markdown]
# # STAGE III

# %%
G_z, F_comp = stage_II_model.predict(taxels_data[0])

# %%
plt.plot(G_z[:, 2])
plt.plot(G_z[:, 2 + 4*3])
# plt.plot(taxels_data[0]['F_z'])

# %%
plt.rcParams["font.family"] = "UGent Panno Text"
plt.rcParams["font.size"] = 14

plt.xlabel("$\overrightarrow{G_0}_z$ [N]")
plt.ylabel("$\overrightarrow{F_z}$ [N]")

plt.grid()
# plt.gca().set_aspect('equal')

plt.plot(G_z_500mHz[:18000, 2], taxels_data[0]['F_z'][:18000])
# Out:
# /tmp/ipykernel_116707/2291990033.py:10: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(G_z_500mHz[:18000, 2], taxels_data[0]['F_z'][:18000])

# %%
plt.rcParams["font.family"] = "UGent Panno Text"
plt.rcParams["font.size"] = 14

plt.xlabel("$\overrightarrow{G_0}_y$ [N]")
plt.ylabel("$\overrightarrow{F_y}$ [N]")

plt.grid()
# plt.gca().set_aspect('equal')

plt.plot(G_z_500mHz[60000:, 1], taxels_data[0]['F_y'][60000:])
# Out:
# /tmp/ipykernel_116707/4127333769.py:10: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(G_z_500mHz[60000:, 1], taxels_data[0]['F_y'][60000:])

# %%
plt.rcParams["font.family"] = "UGent Panno Text"
plt.rcParams["font.size"] = 14

plt.xlabel("$\overrightarrow{G_0}_z$ [N]")
plt.ylabel("$\overrightarrow{F_z}$ [N]")

plt.grid()
# plt.gca().set_aspect('equal')

plt.plot(taxels_data[0]['Z'][:18000], taxels_data[0]['F_z'][:18000])
# Out:
# /tmp/ipykernel_116707/2657121871.py:10: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   plt.plot(taxels_data[0]['Z'][:18000], taxels_data[0]['F_z'][:18000])
